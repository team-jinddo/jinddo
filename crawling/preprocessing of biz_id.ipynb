# %%
import pandas as pd

# %%
df = pd.read_csv('./서울시 일반음식점 인허가 정보.csv')
new_df = df[['사업장명','상세영업상태명', '업태구분명','지번주소', '도로명주소']]

# %% [markdown]
# ## 결측치 제거

# %% [markdown]
# ### '상세영업상태명'

# %%
new_df[new_df.상세영업상태명.isnull()]
# Out:
# Empty DataFrame
# Columns: [사업장명, 상세영업상태명, 업태구분명, 지번주소, 도로명주소]
# Index: []

# %%
# 폐업한 사업장 행 제거
idx = new_df[new_df['상세영업상태명'] == '폐업'].index
new_df.drop(idx, inplace=True)
new_df
# Out:
# /var/folders/7k/h90v2bm11dn7f71xrf48t7xw0000gn/T/ipykernel_53912/502538395.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(idx, inplace=True)
#                   사업장명 상세영업상태명  업태구분명                       지번주소
# 0             매취랑 동대문점      영업     한식      서울특별시 중구 을지로6가 18-137  \
# 1       BLUE BOX(블루박스)      영업     기타        서울특별시 노원구 공릉동 334-3
# 2                  치카바      영업     일식         서울특별시 송파구 가락동 84-6
# 3                  오고보      영업    경양식   서울특별시 송파구 방이동 57 One57빌당
# 4          또봉이통닭 가락본동점      영업  호프/통닭   서울특별시 송파구 가락동 46-11 문종빌딩
# ...                ...     ...    ...                        ...
# 510846            별달맛집      영업     한식   서울특별시 강남구 신사동 609-1 지하1층
# 510847   메가엠지씨커피 신용산역점      영업     기타   서울특별시 용산구 한강로2가 116-1 1층
# ...

# %% [markdown]
# ### '업태구분명'

# %%
new_df[new_df.업태구분명.isnull()]
# Out:
#                     사업장명 상세영업상태명 업태구분명                         지번주소
# 44310            을지로 골뱅이      영업   NaN         서울특별시 종로구 관수동 3-3번지   \
# 48530        고희케이터링 협동조합      영업   NaN    서울특별시 종로구 창성동 100번지 (1층)
# 185880             인디언소울      영업   NaN  서울특별시 도봉구 도봉동 293-2번지 지상1층
# 258266           대독장 교대점      영업   NaN  서울특별시 서초구 서초동 1572-9 지상 2층
# 508380  불닭발땡초동대문엽기떡볶이대치점      영업   NaN          서울특별시 강남구 대치동 908-2
#
#                                      도로명주소
# 44310           서울특별시 종로구 삼일대로20길 17 (관수동)
# 48530      서울특별시 종로구 자하문로12길 17 (창성동,(1층))
# 185880    서울특별시 도봉구 도봉산길 12-15, 지상1층 (도봉동)
# 258266   서울특별시 서초구 반포대로30길 69, 지상 2층 (서초동)
# 508380  서울특별시 강남구 역삼로 406, 지상1층 106호 (대치동)

# %%
# nan값 제거
new_df = new_df.dropna(subset=['업태구분명'], how='any', axis=0)

# %%
# 특정 업태 행 제거
li = ['기타', '기타 휴게음식점', '까페', '다방', '룸살롱', '이동조리', '전통찻집', '출장조리', '커피숍', '키즈카페', '라이브카페', '감성주점', '정종/대포집/소주방', '뷔페식']
new_df.drop(new_df[new_df['업태구분명'].isin(li)].index, inplace=True)
# new_df
# Out:
# /var/folders/7k/h90v2bm11dn7f71xrf48t7xw0000gn/T/ipykernel_53912/2747696086.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(new_df[new_df['업태구분명'].isin(li)].index, inplace=True)

# %%
new_df.업태구분명.unique()
# Out:
# array(['한식', '일식', '경양식', '호프/통닭', '탕류(보신용)', '중국식', '외국음식전문점(인도,태국등)',
#        '식육(숯불구이)', '분식', '김밥(도시락)', '횟집', '패밀리레스트랑', '통닭(치킨)', '냉면집',
#        '패스트푸드', '복어취급'], dtype=object)

# %% [markdown]
# ### '사업장명'

# %%
new_df[new_df.사업장명.isnull()]
# Out:
# Empty DataFrame
# Columns: [사업장명, 상세영업상태명, 업태구분명, 지번주소, 도로명주소]
# Index: []

# %%
# nan값 있는 행 제거
new_df = new_df.dropna(subset=['사업장명'], how='any', axis=0)

# %%
idx = new_df[new_df['사업장명'].str.contains('위원회')].index
new_df.drop(idx, inplace=True)
# new_df

# %% [markdown]
# ### '도로명주소', '지번주소'

# %%
new_df[new_df['도로명주소'].isnull()]
# Out:
#            사업장명 상세영업상태명     업태구분명                                   지번주소 도로명주소
# 219         동순루      영업       중국식                    서울특별시 성동구 하왕십리동 992   NaN
# 590         동대문      영업        한식                   서울특별시 종로구 종로5가 2-1,3   NaN
# 635       품 청국장      영업        분식                서울특별시 종로구 명륜3가 1-209번지    NaN
# 837        마로니에      영업        한식                 서울특별시 종로구 관수동 155-6번지    NaN
# 856       박물관매점      영업        분식                  서울특별시 종로구 세종로 1-57번지    NaN
# ...         ...     ...       ...                                    ...   ...
# 509695     커피미학      영업       경양식  서울특별시 중구 소공동 1 외6필지 롯데호텔및백화점신관(지상12층)   NaN
# 509710     금덕식당      영업        한식                  서울특별시 중구 순화동 198-0 1층   NaN
# 510318       다온      영업       중국식            서울특별시 성동구 홍익동 122-10 (지상1층)   NaN
# 510341  숯불과 닭갈비      영업  식육(숯불구이)                 서울특별시 성북구 석관동 183-4 ,5   NaN
# 510559     삼대냉면      영업        한식               서울특별시 성동구 마장동 793-1 지상1층   NaN
#
# [1075 rows x 5 columns]

# %%
# 도로명주소의 결측치는 지번주소로 대치
new_df['도로명주소'].fillna(new_df['지번주소'], inplace=True)

# %%
idx = new_df[new_df['도로명주소'].str.contains('경기도')].index
new_df.drop(idx, inplace=True)
new_df
# Out:
#                      사업장명 상세영업상태명    업태구분명                             지번주소
# 0                매취랑 동대문점      영업       한식            서울특별시 중구 을지로6가 18-137  \
# 2                     치카바      영업       일식               서울특별시 송파구 가락동 84-6
# 3                     오고보      영업      경양식         서울특별시 송파구 방이동 57 One57빌당
# 4             또봉이통닭 가락본동점      영업    호프/통닭         서울특별시 송파구 가락동 46-11 문종빌딩
# 5                    양이야기      영업  탕류(보신용)  서울특별시 송파구 문정동 644 문정현대지식산업센터1-1
# ...                   ...     ...      ...                              ...
# 510839  불닭발땡초동대문엽기떡볶이쌍문역점      영업       한식              서울특별시 도봉구 창동 659-19
# 510844                DNJ      영업      중국식    서울특별시 노원구 하계동 256-11 보스턴 산부인과
# 510846               별달맛집      영업       한식         서울특별시 강남구 신사동 609-1 지하1층
# 510852               북경반점      영업      중국식              서울특별시 종로구 명륜3가 1-14
# 510853               진도식당      영업       한식              서울특별시 강동구 천호동 456-3
#
# ...

# %% [markdown]
# # 크롤링용 CSV

# %%
import pandas as pd

# %%
df = new_df
df.reset_index(drop=True, inplace=True)
df
# Out:
#                     사업장명 상세영업상태명    업태구분명                             지번주소
# 0               매취랑 동대문점      영업       한식            서울특별시 중구 을지로6가 18-137  \
# 1                    치카바      영업       일식               서울특별시 송파구 가락동 84-6
# 2                    오고보      영업      경양식         서울특별시 송파구 방이동 57 One57빌당
# 3            또봉이통닭 가락본동점      영업    호프/통닭         서울특별시 송파구 가락동 46-11 문종빌딩
# 4                   양이야기      영업  탕류(보신용)  서울특별시 송파구 문정동 644 문정현대지식산업센터1-1
# ...                  ...     ...      ...                              ...
# 98804  불닭발땡초동대문엽기떡볶이쌍문역점      영업       한식              서울특별시 도봉구 창동 659-19
# 98805                DNJ      영업      중국식    서울특별시 노원구 하계동 256-11 보스턴 산부인과
# 98806               별달맛집      영업       한식         서울특별시 강남구 신사동 609-1 지하1층
# 98807               북경반점      영업      중국식              서울특별시 종로구 명륜3가 1-14
# 98808               진도식당      영업       한식              서울특별시 강동구 천호동 456-3
#
#                                                    도로명주소
# ...

# %% [markdown]
# ### 중복 사업장명 제거

# %%
df['사업장명']
df['delete'] = df.사업장명.str.split(' ').str[0]
df
# Out:
#                     사업장명 상세영업상태명    업태구분명                             지번주소
# 0               매취랑 동대문점      영업       한식            서울특별시 중구 을지로6가 18-137  \
# 1                    치카바      영업       일식               서울특별시 송파구 가락동 84-6
# 2                    오고보      영업      경양식         서울특별시 송파구 방이동 57 One57빌당
# 3            또봉이통닭 가락본동점      영업    호프/통닭         서울특별시 송파구 가락동 46-11 문종빌딩
# 4                   양이야기      영업  탕류(보신용)  서울특별시 송파구 문정동 644 문정현대지식산업센터1-1
# ...                  ...     ...      ...                              ...
# 98804  불닭발땡초동대문엽기떡볶이쌍문역점      영업       한식              서울특별시 도봉구 창동 659-19
# 98805                DNJ      영업      중국식    서울특별시 노원구 하계동 256-11 보스턴 산부인과
# 98806               별달맛집      영업       한식         서울특별시 강남구 신사동 609-1 지하1층
# 98807               북경반점      영업      중국식              서울특별시 종로구 명륜3가 1-14
# 98808               진도식당      영업       한식              서울특별시 강동구 천호동 456-3
#
# ...

# %%
# pd.set_option('display.max_seq_items', None)

# %%
de_li = ['라밥(LABAB)', '풍년갈비', '진수성찬', '곱도리탕', '청담동마녀김밥', '써니', '만선호프', '정성한줄','카츠젠', '제이제이', '델리커리', '항아리', '고기로', '한사바리', '산쪼메', '봉피양','본설렁탕', '또와', '옛날칼국수', '현방오백소갈비살', '청솔식당', '육회왕자','이선생', '미향', '딱좋아', '남원정통추어탕', '데일리', '만복식당','엠브로돈까스', '막창굽는', '만족오향족발', '달떡볶이', '쏘시지요','옛고을', '박리분식', '더드림', '미스터피자', '돼지게티', '곱창의', '혼밥대왕','오븐에빠진닭', '친구네', '쉼', '처음처럼', '바지락칼국수', '또와분식', '라온','엄마손칼국수', '양지식당', '옛집', '구름산추어탕', '짚신매운갈비찜', '잭슨피자', '목포세발낙지','the', '칸꼬시', '오부장치킨', '통큰', '리김밥', '빅스타피자', '투썸플레이스', '레드', '추억의','두꺼비식당', '몬스터포', '개성손만두', '해남식당', '브라운', '목포홍탁', '개미식당', '베트남쌀국수', '블루','틈새라면', '할머니', '돈', '한옥마을', '카츠와이찌', '두번먹는명인김치찜', '남원식당', '포케올데이','북경반점', '본', '맛있는집', '다락방', '락궁', '백스비어', '태능숯불갈비', '제육대가', '도야짬뽕','밥도둑', '설맥', '강릉엄지네꼬막집', '성북동', '양가네', '소반', '멘부리', '도화','홍두깨칼국수', '훌랄라', '찌마기', '오렌지', '김삼보', '오가네', '올리브', '일만
터리생고기', '탕화쿵푸마라탕', '라무진', '풍년식당', '육쌈냉면', '토마토김밥', '북경', '가마솥','최가네', '후라이드', '긴자료코', '일품', '한신우동', '양평해장국', '피자스쿨', '풍년집', '대박집','본가', '소풍', '자매식당', '장수식당', '오늘도', '명동찌개마을', '치킨마루', '부어치킨', '불타는','마라공방', '중국성', '가장맛있는족발', '맥주창고', '동경규동', '남도식당', '비스트로','탕화쿵푸', '치킨뱅이', '명가통닭', '가마로강정', '박가네', '미소야', '우리할매떡볶이', '미분당','백채김치찌개', '오토김밥', '김가네김밥', '김밥나라', '배떡', '슬로우캘리', '육전국밥', '불닭발','종로빈대떡', '춘리마라탕', '치킨플러스', '60계', '할매순대국', '홍콩반점', '고기싸롱', '오한수','길동우동', '열정국밥', '우리동네', '육회바른연어', '뜸들이다', '60계치킨', '보드람치킨', '동대문엽기떡볶이','역전우동0410', '을지로골뱅이', '채선당', '정가네', '죽이야기', '두마리찜닭', '소담','비에이치씨', '청진동해장국', '한솥', '비비큐(BBQ)', '오늘은', '하루', '옥된장', '청담', '얌샘김밥','동대문', '북촌손만두', '호치킨', '엄마손', '진미식당', '하남돼지집', '바른치킨','아비꼬', '전주집', '청년다방', '신의주', '멕시카나', '또래오래', '보승회관','야키토리', '서울식당', '생마차', '신전떡볶이', 'The', '압구정', '옛날통닭', '국수나무', '골목집','시골집', '봉추찜닭', '철길부산집', '둘둘치킨', '아지트', '금별맥주', '봉구비어', '고향식당','신의주찹쌀순대', '맛닭꼬', '귀한족발', '명가', '두찜', '고향집', '메가엠지씨커피', '홍콩반점0410','우리식당', '썬더치킨', '호식이두마리치킨', '프랭크버거', 'BBQ', '이가네', '호남식당', '우리집','시골밥상', '페리카나치킨', '오봉집', '펀비어킹', '한솥도시락', '맘스터치', '싸다김밥','지코바', '본도시락', '백소정', '가마치통닭', 'BHC', '노랑통닭', '명륜진사갈비','페리카나', '명동칼국수', '이모네', '자담치킨', '등촌샤브칼국수', '키친스탠다드', '깐부치킨','네네치킨', '남원추어탕', '생활맥주', '본죽&비빔밥', '푸라닭', '본죽', '처갓집양념치킨', '김가네','역전할머니맥주', '투다리', '굽네치킨', '카페', '비비큐', '전주식당', '교촌치킨', '김밥천국','주식회사']

for nm in de_li:
    idx = df[df['사업장명'].str.contains(nm)].index
    df.drop(idx, inplace=True)
# Out:
# /var/folders/7k/h90v2bm11dn7f71xrf48t7xw0000gn/T/ipykernel_53912/3635910342.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   idx = df[df['사업장명'].str.contains(nm)].index

# %%
df = df[['사업장명','상세영업상태명', '업태구분명','도로명주소']]

# %% [markdown]
# # 통합구로 데이터셋 분리

# %%
# 1(강서구 + 양천구)
gs = df[df['도로명주소'].str.contains('강서구')]
yc = df[df['도로명주소'].str.contains('양천구')]

gs_yc = pd.concat([gs, yc])
gs_yc.reset_index(drop=True, inplace=True)

# 2(영등포구 + 구로구 + 금천구)
ydp = df[df['도로명주소'].str.contains('영등포구')]
gr = df[df['도로명주소'].str.contains('구로구')]
gc = df[df['도로명주소'].str.contains('금천구')]

ydp_gr_gc = pd.concat([ydp, gr, gc])
ydp_gr_gc.reset_index(drop=True, inplace=True)

# 3(동작구 + 관악구)
dj = df[df['도로명주소'].str.contains('동작구')]
gw = df[df['도로명주소'].str.contains('관악구')]

dj_gw = pd.concat([dj, gw])
dj_gw.reset_index(drop=True, inplace=True)

# 4(서초구 + 강남구)
sc = df[df['도로명주소'].str.contains('서초구')]
gn = df[df['도로명주소'].str.contains('강남구')]

sc_gn = pd.concat([sc, gn])
sc_gn.reset_index(drop=True, inplace=True)


# 5(송파구 + 강동구)
sp = df[df['도로명주소'].str.contains('송파구')]
gd = df[df['도로명주소'].str.contains('강동구')]

sp_gd = pd.concat([sp, gd])
sp_gd.reset_index(drop=True, inplace=True)


# 6(마포구 + 서대문구 + 은평구)
mp = df[df['도로명주소'].str.contains('마포구')]
sdm = df[df['도로명주소'].str.contains('서대문구')]
yp = df[df['도로명주소'].str.contains('은평구')]

mp_sdm_yp = pd.concat([mp, sdm, yp])
mp_sdm_yp.reset_index(drop=True, inplace=True)

# 7(용산구 + 중구 + 종로구)
ys = df[df['도로명주소'].str.contains('용산')]
j = df[df['도로명주소'].str.contains('중구')]
jr = df[df['도로명주소'].str.contains('종로구')]

ys_j_jr = pd.concat([ys, j, jr])
ys_j_jr.reset_index(drop=True, inplace=True)

# 8(성북구 + 강북구 + 도봉구 + 노원구)
sb = df[df['도로명주소'].str.contains('성북구')]
gb = df[df['도로명주소'].str.contains('강북구')]
db = df[df['도로명주소'].str.contains('도봉구')]
nw = df[df['도로명주소'].str.contains('노원구')]

sb_gb_db_nw = pd.concat([sb, gb, db, nw])
sb_gb_db_nw.reset_index(drop=True, inplace=True)

# 9(광진구 + 성동구 + 동대문구 + 중랑구)
gj = df[df['도로명주소'].str.contains('광진구')]
sd = df[df['도로명주소'].str.contains('성동구')]
ddm = df[df['도로명주소'].str.contains('동대문구')]
jr = df[df['도로명주소'].str.contains('중랑구')]

gj_sd_ddm_jr = pd.concat([gj, sd, ddm, jr])
gj_sd_ddm_jr.reset_index(drop=True, inplace=True)
# Out:
#             사업장명 상세영업상태명     업태구분명
# 0        봉구스 밥버거      영업        한식  \
# 1            모루야      영업        일식
# 2       부대냉삼 이백집      영업        한식
# 3         알촌 마곡점      영업        한식
# 4     냉철한삼겹 화곡동점      영업        한식
# ...          ...     ...       ...
# 4576       아뵤오반점      영업       중국식
# 4577    라밥 목동중앙점      영업        분식
# 4578       섬어부밥상      영업        한식
# 4579         옥천집      영업        한식
# 4580      상도연탄갈비      영업  식육(숯불구이)
#
#                                                   도로명주소
# 0                          서울특별시 강서구 등촌로51길 9, 1층 (등촌동)
# 1          서울특별시 강서구 공항대로 194, 문영 퀸즈파크12차 1층 111호 (마곡동)
# 2          서울특별시 강서구 공항대로 200, 마곡지웰타워 1층 114,115호 (마곡동)
# 3           서울특별시 강서구 수명로 68-35, 웨스트엔드중정 1층 106호 (내발산동)
# 4                        서울특별시 강서구 강서로5나길 115, 1층 (화곡동)
# ...                                                 ...
# 4576  서울특별시 양천구 목동동로 309, 중소기업유통센터(행복한백화점 킴스클럽내) 지하1...
# 4577          서울특별시 양천구 목동서로 285, 황금프라자 지상1층 106호 (신정동)
# ...

# %% [markdown]
# ### 강남구 분리

# %%
gn = df[df['도로명주소'].str.contains('강남구')]
gn.reset_index(drop=True, inplace=True)

# %%
gn.to_csv('./강남구_식당.csv')
